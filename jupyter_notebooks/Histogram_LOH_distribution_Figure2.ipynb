# %%
# %matplotlib inline
import pylab as plt
import mpld3

# %%
import os
hg18=os.listdir("/nfs_exports/genomes/1/Homo_sapiens/1000Genomes/lowcoverage_with_window")
direct="/nfs_exports/genomes/1/Homo_sapiens/1000Genomes/lowcoverage_with_window/"
import numpy as np
dic_sample={}
#Sample	Chr	Length(kb)	Start(kb)	End(kb)
#loh_germline_SJTALL005_color_selection_1M.txt	chr11	16000	98000	114000
for filename in hg18:
    if filename.startswith("summary_loh_germline") and filename.endswith("100K.txt"):
        #print filename
        fullname=direct+filename
        #print fullname
        sample=filename.split("_")[3]
        lines=open(fullname,'r').readlines()
        if len(lines)==1:
            dic_sample[sample]=0
        else:
            for line in lines[1:]:
                record=line.strip(" \r\n").split("\t")
                length=int(record[2]) 
                if sample not in dic_sample:
                    dic_sample[sample]=length
                else:
                    dic_sample[sample]+=length

hg19=os.listdir("/nfs_exports/genomes/1/PCGP/BucketIntermediate/zzhang/germline_loh/html_txt_outputs/hg19_results")
direct2="/nfs_exports/genomes/1/PCGP/BucketIntermediate/zzhang/germline_loh/html_txt_outputs/hg19_results/"
dic_sample2={}
for filename in hg19:
    if filename.startswith("summary_loh_germline") and filename.endswith("100K.txt"):
        #print filename
        fullname=direct2+filename
        #print fullname
        sample=filename.split("_")[3]
        lines=open(fullname,'r').readlines()
        if len(lines)==1:
            dic_sample2[sample]=[0,0,[]]
        else:
            for line in lines[1:]:
                record=line.strip(" \r\n").split("\t")
                length=int(record[2])
                chrom=record[1]
                if sample not in dic_sample2:
                    dic_sample2[sample]=[length,1,[chrom]]   # length, count of different chroms, [chroms]
                else:
                    if chrom not in dic_sample2[sample][2]:
                        dic_sample2[sample][0]+=length
                        dic_sample2[sample][1]+=1
                        dic_sample2[sample][2].append(chrom)
                    else:
                        dic_sample2[sample][0]+=length
                        
hg18_pcgp=os.listdir("/nfs_exports/genomes/1/PCGP/BucketIntermediate/zzhang/germline_loh/html_txt_outputs/hg18_results")
direct3="/nfs_exports/genomes/1/PCGP/BucketIntermediate/zzhang/germline_loh/html_txt_outputs/hg18_results/"
for filename in hg18_pcgp:
    if filename.startswith("summary_loh_germline") and filename.endswith("100K.txt"):
        #print filename
        fullname=direct3+filename
        #print fullname
        sample=filename.split("_")[3]
        lines=open(fullname,'r').readlines()
        if len(lines)==1:
            dic_sample2[sample]=[0,0,[]]
        else:
            for line in lines[1:]:
                record=line.strip(" \r\n").split("\t")
                length=int(record[2])
                chrom=record[1]
                if sample not in dic_sample2:
                    dic_sample2[sample]=[length,1,[chrom]]   # length, count of different chroms, [chroms]
                else:
                    if chrom not in dic_sample2[sample][2]:
                        dic_sample2[sample][0]+=length
                        dic_sample2[sample][1]+=1
                        dic_sample2[sample][2].append(chrom)
                    else:
                        dic_sample2[sample][0]+=length                      
#print dic_sample['SJMB013']
#print len(dic_sample2.values())
#print dic_sample2.keys()[2]
#print dic_sample2.values()[2]
#fig,ax=plt.subplots()
list1=[float(item)/1000 for item in dic_sample.values()]  #change kb into mb
list2=[float(item[0])/1000 for item in dic_sample2.values()]
#list2=[item[0] for item in dic_sample2.values() if item[0]>0]
#print list2 
#print len(list1)
#print list2[1]


#f=plt.hist(list1,alpha=0.5,bins=50,label="1000Genomes",facecolor='green') #,bins=np.logspace(-1, 20.0, 500)
#k=plt.hist(list2,alpha=0.5,bins=50,label="PCGP",facecolor='red') #,bins=np.logspace(-1, 20.0, 500)
#ax.set_title("total length of LOH with minimum length of 1MB (1000genomes hg18)")
MIN, MAX= 1, 300
a=plt.figure()
f=plt.hist(list1, bins = 10 ** np.linspace(np.log10(MIN), np.log10(MAX), 50),alpha=0.5,label="1000Genomes",facecolor='green')
g=plt.hist(list2, bins = 10 ** np.linspace(np.log10(MIN), np.log10(MAX), 50),alpha=0.5,label="PCGP",facecolor='red')
#plt.legend([f, g],["1000genome","PCGP"])
#import matplotlib.patches as mpatches
#red_patch = mpatches.Patch(color='red', label='PCGP')
#green_patch = mpatches.Patch(color='green', label='1000Genomes')
#plt.legend(handles=[red_patch,green_patch])
plt.gca().set_xscale("log")
plt.xlabel("Mb")
plt.ylabel("# of Cases")
plt.legend()
plt.show()
a.savefig("Histogram_LOH_distribution_1MB_minimum_Figure2.pdf",dpi=500,format='pdf')
a.savefig("Histogram_LOH_distribution_1MB_minimum_Figure2.png",dpi=500,format='png')

# %%
import os
hg18=os.listdir("/home/zzhang1/test_code/1000genomes_hg18_processing")
direct="/home/zzhang1/test_code/1000genomes_hg18_processing/"
import numpy as np
dic_sample={}
#Sample	Chr	Length(kb)	Start(kb)	End(kb)
#loh_germline_SJTALL005_color_selection_1M.txt	chr11	16000	98000	114000
for filename in hg18:
    if filename.startswith("summary_loh_germline") and filename.endswith("100K.txt"):
        #print filename
        fullname=direct+filename
        #print fullname
        sample=filename.split("_")[3]
        lines=open(fullname,'r').readlines()
        if len(lines)==1:
            dic_sample[sample]=0
        else:
            for line in lines[1:]:
                record=line.strip(" \r\n").split("\t")
                length=int(record[2]) 
                if sample not in dic_sample:
                    dic_sample[sample]=length
                else:
                    dic_sample[sample]+=length

hg19=os.listdir("/home/zzhang1/test_code/PCGP_hg19_processing")
direct2="/home/zzhang1/test_code/PCGP_hg19_processing/"
dic_sample2={}
for filename in hg19:
    if filename.startswith("summary_loh_germline") and filename.endswith("100K.txt"):
        #print filename
        fullname=direct2+filename
        #print fullname
        sample=filename.split("_")[3]
        lines=open(fullname,'r').readlines()
        if len(lines)==1:
            dic_sample2[sample]=[0,0,[]]
        else:
            for line in lines[1:]:
                record=line.strip(" \r\n").split("\t")
                length=int(record[2])
                chrom=record[1]
                if sample not in dic_sample2:
                    dic_sample2[sample]=[length,1,[chrom]]   # length, count of different chroms, [chroms]
                else:
                    if chrom not in dic_sample2[sample][2]:
                        dic_sample2[sample][0]+=length
                        dic_sample2[sample][1]+=1
                        dic_sample2[sample][2].append(chrom)
                    else:
                        dic_sample2[sample][0]+=length
                        
hg18_pcgp=os.listdir("/home/zzhang1/test_code/PCGP_hg18")
direct3="/home/zzhang1/test_code/PCGP_hg18/"
for filename in hg18_pcgp:
    if filename.startswith("summary_loh_germline") and filename.endswith("100K.txt"):
        #print filename
        fullname=direct3+filename
        #print fullname
        sample=filename.split("_")[3]
        lines=open(fullname,'r').readlines()
        if len(lines)==1:
            dic_sample2[sample]=[0,0,[]]
        else:
            for line in lines[1:]:
                record=line.strip(" \r\n").split("\t")
                length=int(record[2])
                chrom=record[1]
                if sample not in dic_sample2:
                    dic_sample2[sample]=[length,1,[chrom]]   # length, count of different chroms, [chroms]
                else:
                    if chrom not in dic_sample2[sample][2]:
                        dic_sample2[sample][0]+=length
                        dic_sample2[sample][1]+=1
                        dic_sample2[sample][2].append(chrom)
                    else:
                        dic_sample2[sample][0]+=length                      
#print dic_sample['SJMB013']
#print len(dic_sample2.values())
#print dic_sample2.keys()[2]
#print dic_sample2.values()[2]
#fig,ax=plt.subplots()
list1=[float(item)/1000 for item in dic_sample.values()]  #change kb into mb
list2=[float(item[0])/1000 for item in dic_sample2.values()]
#list2=[item[0] for item in dic_sample2.values() if item[0]>0]
#print list2 
#print len(list1)
#print list2[1]


#f=plt.hist(list1,alpha=0.5,bins=50,label="1000Genomes",facecolor='green') #,bins=np.logspace(-1, 20.0, 500)
#k=plt.hist(list2,alpha=0.5,bins=50,label="PCGP",facecolor='red') #,bins=np.logspace(-1, 20.0, 500)
#ax.set_title("total length of LOH with minimum length of 1MB (1000genomes hg18)")
MIN, MAX= 1, 300
a=plt.figure()
f=plt.hist(list1, bins = 10 ** np.linspace(np.log10(MIN), np.log10(MAX), 50),alpha=0.5,label="1000Genomes",facecolor='green')
g=plt.hist(list2, bins = 10 ** np.linspace(np.log10(MIN), np.log10(MAX), 50),alpha=0.5,label="PCGP",facecolor='red')
#plt.legend([f, g],["1000genome","PCGP"])
#import matplotlib.patches as mpatches
#red_patch = mpatches.Patch(color='red', label='PCGP')
#green_patch = mpatches.Patch(color='green', label='1000Genomes')
#plt.legend(handles=[red_patch,green_patch])
plt.gca().set_xscale("log")
plt.xlabel("Mb")
plt.ylabel("# of Cases")
plt.legend()
plt.show()
a.savefig("Histogram_LOH_distribution_5MB_minimum_Figure2.pdf",dpi=500,format='pdf')
a.savefig("Histogram_LOH_distribution_5MB_minimum_Figure2.png",dpi=500,format='png')

# %%
import os
hg18=os.listdir("/nfs_exports/genomes/1/Homo_sapiens/1000Genomes/lowcoverage_with_window")
direct="/nfs_exports/genomes/1/Homo_sapiens/1000Genomes/lowcoverage_with_window/"
import numpy as np
dic_sample={}
#Sample	Chr	Length(kb)	Start(kb)	End(kb)
#loh_germline_SJTALL005_color_selection_1M.txt	chr11	16000	98000	114000
for filename in hg18:
    if filename.startswith("summary_loh_germline") and filename.endswith("100K.txt"):
        #print filename
        fullname=direct+filename
        #print fullname
        sample=filename.split("_")[3]
        lines=open(fullname,'r').readlines()
        if len(lines)==1:
            dic_sample[sample]=0
        else:
            for line in lines[1:]:
                record=line.strip(" \r\n").split("\t")
                length=int(record[2]) 
                if sample not in dic_sample:
                    dic_sample[sample]=length
                else:
                    dic_sample[sample]=max(length,dic_sample[sample])

hg19=os.listdir("/nfs_exports/genomes/1/PCGP/BucketIntermediate/zzhang/germline_loh/html_txt_outputs/hg19_results")
direct2="/nfs_exports/genomes/1/PCGP/BucketIntermediate/zzhang/germline_loh/html_txt_outputs/hg19_results/"
dic_sample2={}
for filename in hg19:
    if filename.startswith("summary_loh_germline") and filename.endswith("100K.txt"):
        #print filename
        fullname=direct2+filename
        #print fullname
        sample=filename.split("_")[3]
        lines=open(fullname,'r').readlines()
        if len(lines)==1:
            dic_sample2[sample]=[0,0,[]]
        else:
            for line in lines[1:]:
                record=line.strip(" \r\n").split("\t")
                length=int(record[2])
                chrom=record[1]
                if sample not in dic_sample2:
                    dic_sample2[sample]=[length,1,[chrom]]   # length, count of different chroms, [chroms]
                else:
                    if chrom not in dic_sample2[sample][2]:
                        #dic_sample2[sample][0]+=length
                        dic_sample2[sample][0]=max(length,dic_sample2[sample][0])
                        dic_sample2[sample][1]+=1
                        dic_sample2[sample][2].append(chrom)
                    else:
                        dic_sample2[sample][0]=max(length,dic_sample2[sample][0])
                        
hg18_pcgp=os.listdir("/nfs_exports/genomes/1/PCGP/BucketIntermediate/zzhang/germline_loh/html_txt_outputs/hg18_results")
direct3="/nfs_exports/genomes/1/PCGP/BucketIntermediate/zzhang/germline_loh/html_txt_outputs/hg18_results/"
for filename in hg18_pcgp:
    if filename.startswith("summary_loh_germline") and filename.endswith("100K.txt"):
        #print filename
        fullname=direct3+filename
        #print fullname
        sample=filename.split("_")[3]
        lines=open(fullname,'r').readlines()
        if len(lines)==1:
            dic_sample2[sample]=[0,0,[]]
        else:
            for line in lines[1:]:
                record=line.strip(" \r\n").split("\t")
                length=int(record[2])
                chrom=record[1]
                if sample not in dic_sample2:
                    dic_sample2[sample]=[length,1,[chrom]]   # length, count of different chroms, [chroms]
                else:
                    if chrom not in dic_sample2[sample][2]:
                        dic_sample2[sample][0]=max(length,dic_sample2[sample][0])
                        dic_sample2[sample][1]+=1
                        dic_sample2[sample][2].append(chrom)
                    else:
                        dic_sample2[sample][0]=max(length,dic_sample2[sample][0])                  
#print dic_sample['SJMB013']
#print len(dic_sample2.values())
#print dic_sample2.keys()[2]
#print dic_sample2.values()[2]
#fig,ax=plt.subplots()
list1=[float(item)/1000 for item in dic_sample.values()]  #change kb into mb
list2=[float(item[0])/1000 for item in dic_sample2.values()]
#list2=[item[0] for item in dic_sample2.values() if item[0]>0]
#print list2 
#print len(list1)
#print list2[1]


#f=plt.hist(list1,alpha=0.5,bins=50,label="1000Genomes",facecolor='green') #,bins=np.logspace(-1, 20.0, 500)
#k=plt.hist(list2,alpha=0.5,bins=50,label="PCGP",facecolor='red') #,bins=np.logspace(-1, 20.0, 500)
#ax.set_title("total length of LOH with minimum length of 1MB (1000genomes hg18)")
MIN, MAX= 1, 300
a=plt.figure()
f=plt.hist(list1, bins = 10 ** np.linspace(np.log10(MIN), np.log10(MAX), 50),alpha=0.5,label="1000Genomes",facecolor='green')
g=plt.hist(list2, bins = 10 ** np.linspace(np.log10(MIN), np.log10(MAX), 50),alpha=0.5,label="PCGP",facecolor='red')
#plt.legend([f, g],["1000genome","PCGP"])
#import matplotlib.patches as mpatches
#red_patch = mpatches.Patch(color='red', label='PCGP')
#green_patch = mpatches.Patch(color='green', label='1000Genomes')
#plt.legend(handles=[red_patch,green_patch])
plt.gca().set_xscale("log")
plt.xlabel("Mb")
plt.ylabel("# of Cases")
plt.legend()
plt.show()
a.savefig("Histogram_Max-Length-LOH_distribution_1MB_minimum_Figure2.pdf",dpi=500,format='pdf')
a.savefig("Histogram_Max-Length-LOH_distribution_1MB_minimum_Figure2.png",dpi=500,format='png')

# %%
import os
hg18=os.listdir("/home/zzhang1/test_code/1000genomes_hg18_processing")
direct="/home/zzhang1/test_code/1000genomes_hg18_processing/"
import numpy as np
dic_sample={}
#Sample	Chr	Length(kb)	Start(kb)	End(kb)
#loh_germline_SJTALL005_color_selection_1M.txt	chr11	16000	98000	114000
for filename in hg18:
    if filename.startswith("summary_loh_germline") and filename.endswith("100K.txt"):
        #print filename
        fullname=direct+filename
        #print fullname
        sample=filename.split("_")[3]
        lines=open(fullname,'r').readlines()
        if len(lines)==1:
            dic_sample[sample]=0
        else:
            for line in lines[1:]:
                record=line.strip(" \r\n").split("\t")
                length=int(record[2]) 
                if sample not in dic_sample:
                    dic_sample[sample]=length
                else:
                    dic_sample[sample]=max(length,dic_sample[sample])

hg19=os.listdir("/home/zzhang1/test_code/PCGP_hg19_processing")
direct2="/home/zzhang1/test_code/PCGP_hg19_processing/"
dic_sample2={}
for filename in hg19:
    if filename.startswith("summary_loh_germline") and filename.endswith("100K.txt"):
        #print filename
        fullname=direct2+filename
        #print fullname
        sample=filename.split("_")[3]
        lines=open(fullname,'r').readlines()
        if len(lines)==1:
            dic_sample2[sample]=[0,0,[]]
        else:
            for line in lines[1:]:
                record=line.strip(" \r\n").split("\t")
                length=int(record[2])
                chrom=record[1]
                if sample not in dic_sample2:
                    dic_sample2[sample]=[length,1,[chrom]]   # length, count of different chroms, [chroms]
                else:
                    if chrom not in dic_sample2[sample][2]:
                        dic_sample2[sample][0]=max(length,dic_sample2[sample][0])
                        dic_sample2[sample][1]+=1
                        dic_sample2[sample][2].append(chrom)
                    else:
                        dic_sample2[sample][0]=max(length,dic_sample2[sample][0])
                        
hg18_pcgp=os.listdir("/home/zzhang1/test_code/PCGP_hg18")
direct3="/home/zzhang1/test_code/PCGP_hg18/"
for filename in hg18_pcgp:
    if filename.startswith("summary_loh_germline") and filename.endswith("100K.txt"):
        #print filename
        fullname=direct3+filename
        #print fullname
        sample=filename.split("_")[3]
        lines=open(fullname,'r').readlines()
        if len(lines)==1:
            dic_sample2[sample]=[0,0,[]]
        else:
            for line in lines[1:]:
                record=line.strip(" \r\n").split("\t")
                length=int(record[2])
                chrom=record[1]
                if sample not in dic_sample2:
                    dic_sample2[sample]=[length,1,[chrom]]   # length, count of different chroms, [chroms]
                else:
                    if chrom not in dic_sample2[sample][2]:
                        dic_sample2[sample][0]=max(length,dic_sample2[sample][0])
                        dic_sample2[sample][1]+=1
                        dic_sample2[sample][2].append(chrom)
                    else:
                        dic_sample2[sample][0]=max(length,dic_sample2[sample][0])                      
#print dic_sample['SJMB013']
#print len(dic_sample2.values())
#print dic_sample2.keys()[2]
#print dic_sample2.values()[2]
#fig,ax=plt.subplots()
list1=[float(item)/1000 for item in dic_sample.values()]  #change kb into mb
list2=[float(item[0])/1000 for item in dic_sample2.values()]
#list2=[item[0] for item in dic_sample2.values() if item[0]>0]
#print list2 
#print len(list1)
#print list2[1]


#f=plt.hist(list1,alpha=0.5,bins=50,label="1000Genomes",facecolor='green') #,bins=np.logspace(-1, 20.0, 500)
#k=plt.hist(list2,alpha=0.5,bins=50,label="PCGP",facecolor='red') #,bins=np.logspace(-1, 20.0, 500)
#ax.set_title("total length of LOH with minimum length of 1MB (1000genomes hg18)")
MIN, MAX= 1, 300
a=plt.figure()
f=plt.hist(list1, bins = 10 ** np.linspace(np.log10(MIN), np.log10(MAX), 50),alpha=0.5,label="1000Genomes",facecolor='green')
g=plt.hist(list2, bins = 10 ** np.linspace(np.log10(MIN), np.log10(MAX), 50),alpha=0.5,label="PCGP",facecolor='red')
#plt.legend([f, g],["1000genome","PCGP"])
#import matplotlib.patches as mpatches
#red_patch = mpatches.Patch(color='red', label='PCGP')
#green_patch = mpatches.Patch(color='green', label='1000Genomes')
#plt.legend(handles=[red_patch,green_patch])
plt.gca().set_xscale("log")
plt.xlabel("Mb")
plt.ylabel("# of Cases")
plt.legend()
plt.show()
a.savefig("Histogram_Max-Length-LOH_distribution_5MB_minimum_Figure2.pdf",dpi=500,format='pdf')
a.savefig("Histogram_Max-Length-LOH_distribution_5MB_minimum_Figure2.png",dpi=500,format='png')
